# %%
Price = [110, 105, 115, 120, 110, 130, 150, 100, 105]

# %% [markdown]
# #### Import pandas, create dataframe

# %%
import pandas as pd

# %%
df = pd.DataFrame({'price': Price})
df
# Out:
#    price
# 0    110
# 1    105
# 2    115
# 3    120
# 4    110
# 5    130
# 6    150
# 7    100
# 8    105

# %% [markdown]
# ### Create excel file

# %%
df.to_excel('feature_price.xlsx', index=False)
print('excel file created successfully.')
# Out:
# excel file created successfully.

# %%
df = pd.read_excel('feature_price.xlsx')
df
# Out:
#    price
# 0    110
# 1    105
# 2    115
# 3    120
# 4    110
# 5    130
# 6    150
# 7    100
# 8    105

# %% [markdown]
# ## Techniques to perform for Feature Transformation:
# ▪ Normalization
# ▪ Standardization
# ▪ Log Transformation
# ▪ Robust Scaler
# ▪ Max Absolute Scaler

# %% [markdown]
# ## Normalization

# %%
min_price = df.price.min()
max_price = df.price.max()

# %%
min_price
# Out:
# 100

# %%
max_price
# Out:
# 150

# %%
df['price_norm_manual'] = (df.price - min_price ) / (max_price - min_price)
df
# Out:
#    price  price_norm_manual
# 0    110                0.2
# 1    105                0.1
# 2    115                0.3
# 3    120                0.4
# 4    110                0.2
# 5    130                0.6
# 6    150                1.0
# 7    100                0.0
# 8    105                0.1

# %%
from sklearn.preprocessing import MinMaxScaler
mmx = MinMaxScaler()

# %%
df['price_norm_sklearn'] = mmx.fit_transform(df[['price']])
df.head()
# Out:
#    price  price_norm_manual  price_norm_sklearn
# 0    110                0.2                 0.2
# 1    105                0.1                 0.1
# 2    115                0.3                 0.3
# 3    120                0.4                 0.4
# 4    110                0.2                 0.2

# %% [markdown]
# ## Standardization

# %%
mean_price = df.price.mean()
std = df.price.std()

# %%
df['price_std_manual'] = (df['price'] - mean_price) / std
df
# Out:
#    price  price_norm_manual  price_norm_sklearn  price_std_manual
# 0    110                0.2                 0.2         -0.392544
# 1    105                0.1                 0.1         -0.713717
# 2    115                0.3                 0.3         -0.071372
# 3    120                0.4                 0.4          0.249801
# 4    110                0.2                 0.2         -0.392544
# 5    130                0.6                 0.6          0.892146
# 6    150                1.0                 1.0          2.176837
# 7    100                0.0                 0.0         -1.034890
# 8    105                0.1                 0.1         -0.713717

# %%
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()

# %%
df['price_std_sklearn'] = scaler.fit_transform(df[['price']])
df.head()
# Out:
#    price  price_norm_manual  price_norm_sklearn  price_std_manual  \
# 0    110                0.2                 0.2         -0.392544
# 1    105                0.1                 0.1         -0.713717
# 2    115                0.3                 0.3         -0.071372
# 3    120                0.4                 0.4          0.249801
# 4    110                0.2                 0.2         -0.392544
#
#    price_std_sklearn
# 0          -0.416356
# 1          -0.757011
# 2          -0.075701
# 3           0.264954
# 4          -0.416356

# %% [markdown]
# ## Log Transformation

# %%
import numpy as np

# %%
df['price_log_manual'] = np.log10(df.price)
df.head()
# Out:
#    price  price_norm_manual  price_norm_sklearn  price_std_manual  \
# 0    110                0.2                 0.2         -0.392544
# 1    105                0.1                 0.1         -0.713717
# 2    115                0.3                 0.3         -0.071372
# 3    120                0.4                 0.4          0.249801
# 4    110                0.2                 0.2         -0.392544
#
#    price_std_sklearn  price_log_manual
# 0          -0.416356          2.041393
# 1          -0.757011          2.021189
# 2          -0.075701          2.060698
# 3           0.264954          2.079181
# 4          -0.416356          2.041393

# %%
from sklearn.preprocessing import FunctionTransformer
log_10 = FunctionTransformer(np.log10, validate=True)

# %%
df['price_log_sklearn'] = log_10.transform(df[['price']])
df.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but FunctionTransformer was fitted without feature names
#   warnings.warn(
#    price  price_norm_manual  price_norm_sklearn  price_std_manual  \
# 0    110                0.2                 0.2         -0.392544
# 1    105                0.1                 0.1         -0.713717
# 2    115                0.3                 0.3         -0.071372
# 3    120                0.4                 0.4          0.249801
# 4    110                0.2                 0.2         -0.392544
#
#    price_std_sklearn  price_log_manual  price_log_sklearn
# 0          -0.416356          2.041393           2.041393
# 1          -0.757011          2.021189           2.021189
# 2          -0.075701          2.060698           2.060698
# 3           0.264954          2.079181           2.079181
# 4          -0.416356          2.041393           2.041393

# %% [markdown]
# ## Robust Scaler

# %%
IQR = df.price.quantile(.75) - df.price.quantile(.25)
med = df.price.median()

# %%
df['price_robust_manual'] = (df.price - med) / IQR
df
# Out:
#    price  price_norm_manual  price_norm_sklearn  price_std_manual  \
# 0    110                0.2                 0.2         -0.392544
# 1    105                0.1                 0.1         -0.713717
# 2    115                0.3                 0.3         -0.071372
# 3    120                0.4                 0.4          0.249801
# 4    110                0.2                 0.2         -0.392544
# 5    130                0.6                 0.6          0.892146
# 6    150                1.0                 1.0          2.176837
# 7    100                0.0                 0.0         -1.034890
# 8    105                0.1                 0.1         -0.713717
#
#    price_std_sklearn  price_log_manual  price_log_sklearn  price_robust_manual
# 0          -0.416356          2.041393           2.041393             0.000000
# 1          -0.757011          2.021189           2.021189            -0.333333
# 2          -0.075701          2.060698           2.060698             0.333333
# 3           0.264954          2.079181           2.079181             0.666667
# 4          -0.416356          2.041393           2.041393             0.000000
# 5           0.946264          2.113943           2.113943             1.333333
# 6           2.308884          2.176091           2.176091             2.666667
# 7          -1.097666          2.000000           2.000000            -0.666667
# 8          -0.757011          2.021189           2.021189            -0.333333

# %%
from sklearn.preprocessing import RobustScaler
robust_scaler = RobustScaler()

# %%
df['price_robust_sklearn'] = robust_scaler.fit_transform(df[['price']])
df.head()
# Out:
#    price  price_norm_manual  price_norm_sklearn  price_std_manual  \
# 0    110                0.2                 0.2         -0.392544
# 1    105                0.1                 0.1         -0.713717
# 2    115                0.3                 0.3         -0.071372
# 3    120                0.4                 0.4          0.249801
# 4    110                0.2                 0.2         -0.392544
#
#    price_std_sklearn  price_log_manual  price_log_sklearn  \
# 0          -0.416356          2.041393           2.041393
# 1          -0.757011          2.021189           2.021189
# 2          -0.075701          2.060698           2.060698
# 3           0.264954          2.079181           2.079181
# 4          -0.416356          2.041393           2.041393
#
#    price_robust_manual  price_robust_sklearn
# 0             0.000000              0.000000
# 1            -0.333333             -0.333333
# 2             0.333333              0.333333
# 3             0.666667              0.666667
# 4             0.000000              0.000000

# %% [markdown]
# ## Max Absolute Scaler

# %%
df['price_max_manual'] = df.price / df.price.max()
df
# Out:
#    price  price_norm_manual  price_norm_sklearn  price_std_manual  \
# 0    110                0.2                 0.2         -0.392544
# 1    105                0.1                 0.1         -0.713717
# 2    115                0.3                 0.3         -0.071372
# 3    120                0.4                 0.4          0.249801
# 4    110                0.2                 0.2         -0.392544
# 5    130                0.6                 0.6          0.892146
# 6    150                1.0                 1.0          2.176837
# 7    100                0.0                 0.0         -1.034890
# 8    105                0.1                 0.1         -0.713717
#
#    price_std_sklearn  price_log_manual  price_log_sklearn  \
# 0          -0.416356          2.041393           2.041393
# 1          -0.757011          2.021189           2.021189
# 2          -0.075701          2.060698           2.060698
# 3           0.264954          2.079181           2.079181
# 4          -0.416356          2.041393           2.041393
# 5           0.946264          2.113943           2.113943
# 6           2.308884          2.176091           2.176091
# 7          -1.097666          2.000000           2.000000
# 8          -0.757011          2.021189           2.021189
#
#    price_robust_manual  price_robust_sklearn  price_max_manual
# 0             0.000000              0.000000          0.733333
# 1            -0.333333             -0.333333          0.700000
# 2             0.333333              0.333333          0.766667
# 3             0.666667              0.666667          0.800000
# 4             0.000000              0.000000          0.733333
# 5             1.333333              1.333333          0.866667
# 6             2.666667              2.666667          1.000000
# 7            -0.666667             -0.666667          0.666667
# 8            -0.333333             -0.333333          0.700000

# %%
from sklearn.preprocessing import MaxAbsScaler
mx = MaxAbsScaler()

# %%
df['price_max_sklearn'] = mx.fit_transform(df[['price']])
df.head()
# Out:
#    price  price_norm_manual  price_norm_sklearn  price_std_manual  \
# 0    110                0.2                 0.2         -0.392544
# 1    105                0.1                 0.1         -0.713717
# 2    115                0.3                 0.3         -0.071372
# 3    120                0.4                 0.4          0.249801
# 4    110                0.2                 0.2         -0.392544
#
#    price_std_sklearn  price_log_manual  price_log_sklearn  \
# 0          -0.416356          2.041393           2.041393
# 1          -0.757011          2.021189           2.021189
# 2          -0.075701          2.060698           2.060698
# 3           0.264954          2.079181           2.079181
# 4          -0.416356          2.041393           2.041393
#
#    price_robust_manual  price_robust_sklearn  price_max_manual  \
# 0             0.000000              0.000000          0.733333
# 1            -0.333333             -0.333333          0.700000
# 2             0.333333              0.333333          0.766667
# 3             0.666667              0.666667          0.800000
# 4             0.000000              0.000000          0.733333
#
#    price_max_sklearn
# 0           0.733333
# 1           0.700000
# 2           0.766667
# 3           0.800000
# 4           0.733333
